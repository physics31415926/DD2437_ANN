# %%
import math as math
import numpy as np
import matplotlib.pyplot as plt

step = 0.1
x_train = np.arange(0, 2*math.pi, step)
x_test = np.arange(0.05, 2*math.pi, step)
y_train = np.zeros(len(x_train))
y_test = np.zeros(len(x_test))
n = len(x_train)
for i in range(n):
    y_train[i] = math.sin(2*x_train[i])
for i in range(len(x_test)):
    y_test[i] = math.sin(2*x_test[i])
plt.scatter(x_train, y_train, color='red', label='Training data')
plt.title('Training data')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.show()
plt.scatter(x_test, y_test, color='blue', label='Test data')
plt.title('Test data')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Generate training set and test set for y=sin(2x).

# %%
step2 = 1.2

centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
sigma = 1
weights = np.random.normal(1, 1, N)
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))

temp1 = np.dot(hidden_out.T, hidden_out)
temp2 = np.dot(hidden_out.T, y_train)
weights = np.dot(np.linalg.inv(temp1), temp2)
print(weights)
hidden_out2 = np.zeros((len(x_test), N))
results = np.zeros(len(x_test))
for i in range(len(x_test)):
    for j in range(N):
        hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_test[i]-centers[j]))
    results[i] = np.dot(hidden_out2[i, :], weights)

error = np.mean(np.abs(y_test - results))
print('Error:', error)
plt.plot(x_test, results, color='red',label='Predicted data')
plt.plot(x_test, y_test, color='blue', label='Test data')
plt.legend()
plt.title('Performance on test set')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# [-1.18812628  3.16920801 -4.23276304  3.63928029 -1.79056396  0.02704508]
# Error: 0.08386774965276786

# %% [markdown]
# y = sin(2x)
# centers = [0,1.2,2.4,3.6,4.8,6.0]
# sigma, that is, the width of RBF units is 1.
# Number of RBF units is 6.
# We can obtain the absolute residual error below 0.1.

# %%
step2 = 1
centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
sigma = 1.5
weights = np.random.normal(1, 1, N)
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))

temp1 = np.dot(hidden_out.T, hidden_out)
temp2 = np.dot(hidden_out.T, y_train)
weights = np.dot(np.linalg.inv(temp1), temp2)
print(weights)
hidden_out2 = np.zeros((len(x_test), N))
results = np.zeros(len(x_test))
for i in range(len(x_test)):
    for j in range(N):
        hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_test[i]-centers[j]))
    results[i] = np.dot(hidden_out2[i, :], weights)

error = np.mean(np.abs(y_test - results))
print('Error:', error)
plt.plot(x_test, results, color='red',label='Predicted data')
plt.plot(x_test, y_test, color='blue', label='Test data')
plt.legend()
plt.title('Performance on test set')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# [-11.74837281  21.08531602  -7.408248   -24.56842468  46.85601734
#  -40.18625691  15.83274593]
# Error: 0.009866935509999621

# %% [markdown]
# y = sin(2x)
# centers = [0,1,2,3,4,5,6]
# sigma, that is, the width of RBF units is 1.5.
# Number of RBF units is 7.
# We can obtain the absolute residual error below 0.01.

# %%
step2 = 0.5
sigma = 1.2
centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
weights = np.random.normal(1, 1, N)
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))

temp1 = np.dot(hidden_out.T, hidden_out)
temp2 = np.dot(hidden_out.T, y_train)
weights = np.dot(np.linalg.inv(temp1), temp2)
print(weights)
hidden_out2 = np.zeros((len(x_test), N))
results = np.zeros(len(x_test))
for i in range(len(x_test)):
    for j in range(N):
        hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_test[i]-centers[j]))
    results[i] = np.dot(hidden_out2[i, :], weights)

error = np.mean(np.abs(y_test - results))
print('Error:', error)
plt.plot(x_test, results, color='red',label='Predicted data')
plt.plot(x_test, y_test, color='blue', label='Test data')
plt.legend()
plt.title('Performance on test set')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# [  15.62791061  -97.97132874  240.66967773 -341.17150879  312.37939453
#  -134.60180664 -132.50244141  347.99072266 -410.22241211  329.26806641
#  -174.11035156   44.15660095    0.61605072]
# Error: 0.00041667416143425324

# %% [markdown]
# y = sin(2x)
# centers = [0,0.7,1.4,2.1,2.8,3.5,4.2,4.9,5.6]
# sigma, that is, the width of RBF units is 2.
# Number of RBF units is 9.
# We can obtain the absolute residual error below 0.001.

# %%
import math as math
import numpy as np
import matplotlib.pyplot as plt

step = 0.1
x_train = np.arange(0, 2*math.pi, step)
x_test = np.arange(0.05, 2*math.pi, step)
y_train = np.zeros(len(x_train))
y_test = np.zeros(len(x_test))
n = len(x_train)
for i in range(n):
    y_train[i] = math.sin(2*x_train[i])
    if y_train[i]<0:
        y_train[i] = -1
    if y_train[i]>=0:
        y_train[i] = 1
for i in range(len(x_test)):
    y_test[i] = math.sin(2*x_test[i])
    if y_test[i]<0:
        y_test[i] = -1
    if y_test[i]>=0:
        y_test[i] = 1
plt.scatter(x_train, y_train, color='red', label='Training data')
plt.title('Training data')
plt.legend()
plt.show()
plt.scatter(x_test, y_test, color='blue', label='Test data')
plt.title('Test data')
plt.legend()
plt.show()

# %% [markdown]
# Generate training set and test set for y=square(2x).

# %%
nodes = 25
sigma = 0.50
centers = np.zeros(nodes)
for i in range(1,nodes):
    centers[i] = i*2*math.pi/(nodes-1)
N = nodes
weights = np.random.normal(1, 1, N)
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))

temp1 = np.dot(hidden_out.T, hidden_out)
temp2 = np.dot(hidden_out.T, y_train)
weights = np.dot(np.linalg.inv(temp1), temp2)
print(weights)
hidden_out2 = np.zeros((len(x_test), N))
results = np.zeros(len(x_test))
for i in range(len(x_test)):
    for j in range(N):
        hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_test[i]-centers[j]))
    results[i] = np.dot(hidden_out2[i, :], weights)

error = np.mean(np.abs(y_test - results))
print('Error:', error)
plt.plot(x_test, results, color='red',label='Predicted data')
plt.plot(x_test, y_test, color='blue', label='Test data')
plt.legend()
plt.title('Performance on test set')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# [   216.94342476  -1117.03939974   3249.40383768  -6992.06829309
#   12330.56672287 -18690.02269936  24910.24033356 -29424.66612625
#   30695.88208961 -27719.16020393  20356.83296204  -9459.55542564
#   -3264.3520031   15615.82583237 -25482.35326004  31387.48643112
#  -32789.71616364  30129.90423965 -24631.77864456  17914.18592072
#  -11481.20400238   6334.30638885  -2868.14406776    962.03070688
#    -182.69461995]
# Error: 0.13875124884823473

# %%
import math as math
import numpy as np
import matplotlib.pyplot as plt

step = 0.1
x_train = np.arange(0, 2*math.pi, step)
x_test = np.arange(0.05, 2*math.pi, step)
y_train = np.zeros(len(x_train))
y_test = np.zeros(len(x_test))
n = len(x_train)
for i in range(n):
    y_train[i] = math.sin(2*x_train[i])
    if y_train[i]<0:
        y_train[i] = -1
    if y_train[i]>=0:
        y_train[i] = 1
for i in range(len(x_test)):
    y_test[i] = math.sin(2*x_test[i])
    if y_test[i]<0:
        y_test[i] = -1
    if y_test[i]>=0:
        y_test[i] = 1

sigma = 0.5
centers = [0,math.pi/4,math.pi*2/4,math.pi*3/4,math.pi,math.pi*5/4,math.pi*6/4,math.pi*7/4,math.pi*2]
N = len(centers)
weights = np.random.normal(1, 1, N)
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))

temp1 = np.dot(hidden_out.T, hidden_out)
temp2 = np.dot(hidden_out.T, y_train)
weights = np.dot(np.linalg.inv(temp1), temp2)
print(weights)
hidden_out2 = np.zeros((len(x_test), N))
results = np.zeros(len(x_test))
for i in range(len(x_test)):
    for j in range(N):
        hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_test[i]-centers[j]))
    results[i] = np.dot(hidden_out2[i, :], weights)
for i in range(len(x_test)):
    if results[i]<0:
        results[i] = -1
    if results[i]>=0:
        results[i] = 1
error = np.mean(np.abs(y_test - results))
print('Error:', error)
plt.plot(x_test, results, color='red',label='Predicted data')
plt.plot(x_test, y_test, color='blue', label='Test data')
plt.legend()
plt.title('Performance on test set')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# [ 0.48901305  1.00557833  0.09560851 -1.35110443 -0.01021064  1.32196152
#  -0.00777809 -1.0822051  -0.38251894]
# Error: 0.0

# %% [markdown]
# Simple transformation: If the output >= 0, let the output = 1. If the output <0, let the output = -1.
# We need 9 RBF units: 0,pi/4,pi/2,3*pi/4,pi,5*pi/4,3*pi/2,7*pi/4,2*pi
# It is very useful in digital communication, e.g.,decoding the transmitted bits.

# %%
import math as math
import numpy as np

step = 0.1
x_train = np.arange(0, 2*math.pi, step)
np.random.shuffle(x_train)
x_test = np.arange(0.05, 2*math.pi, step)
y_train = np.zeros(len(x_train))
y_test = np.zeros(len(x_test))
n = len(x_train)
for i in range(n):
    y_train[i] = math.sin(2*x_train[i])
for i in range(len(x_test)):
    y_test[i] = math.sin(2*x_test[i])
noise = np.random.normal(0, 0.1, len(y_train))
y_train = y_train + noise
y_test = y_test + noise
plt.scatter(x_train, y_train, color='red', label='Training data')
plt.title('Training data')
plt.legend()
plt.show()
plt.scatter(x_test, y_test, color='blue', label='Test data')
plt.title('Test data')
plt.legend()
plt.show()
weights = np.random.normal(1, 1, N)

# %%
step2 = 0.5
sigma = 0.2

rate = 0.3
centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
delta_w = np.zeros(N)

hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
    train_result = np.dot(hidden_out[i], weights)
    train_error = y_train[i] - train_result
    delta_w = rate*train_error*hidden_out[i]
    weights = weights + delta_w

print(weights)
hidden_out2 = np.zeros((len(x_test), N))
results = np.zeros(len(x_test))
for i in range(len(x_test)):
    for j in range(N):
        hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_test[i]-centers[j]))
    results[i] = np.dot(hidden_out2[i], weights)

error = np.mean(np.abs(y_test - results))
print('Error:', error)
plt.plot(x_test, results, color='red',label='Predicted data')
plt.plot(x_test, y_test, color='blue', label='Test data')
plt.legend()
plt.title('Performance on test set')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# [ 0.35082545  0.69393295  1.14075031 -0.03202427 -0.61335395 -0.91052003
#  -0.23930958  0.83076707  0.82044805  0.40138568 -0.77842226 -0.8916405
#  -0.44218976]
# Error: 0.15710283532993155

# %% [markdown]
# y = sin(2x)
# centers = 0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6.
# The result of online learning approach on test set.

# %%
import math as math
import numpy as np

step = 0.1
x_train = np.arange(0, 2*math.pi, step)
np.random.shuffle(x_train)
x_test = np.arange(0.05, 2*math.pi, step)
y_train = np.zeros(len(x_train))
y_test = np.zeros(len(x_test))
n = len(x_train)
for i in range(n):
    y_train[i] = math.sin(2*x_train[i])
for i in range(len(x_test)):
    y_test[i] = math.sin(2*x_test[i])
noise = np.random.normal(0, 0.1, len(y_train))
y_train = y_train + noise
y_test = y_test + noise

rate = 0.3

step2 = 2
centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
sigma_array = np.zeros(20)
error = np.zeros(20)
for k in range(20):
    sigma = 0.05*(k+1)
    sigma_array[k] = sigma
    delta_w = np.zeros(N)
    weights = np.random.normal(1, 1, N)
    hidden_out = np.zeros((n, N))
    for i in range(n):
        for j in range(N):
            hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
        train_result = np.dot(hidden_out[i], weights)
        train_error = y_train[i] - train_result
        delta_w = rate*train_error*hidden_out[i]
        weights = weights + delta_w
    hidden_out2 = np.zeros((len(x_test), N))
    results = np.zeros(len(x_test))
    for i in range(len(x_test)):
        for j in range(N):
            hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_test[i]-centers[j]))
        results[i] = np.dot(hidden_out2[i], weights)
    error[k] = np.mean(np.abs(y_test - results))
plt.plot(sigma_array, error, label='Number of nodes = 4')

step2 = 1
centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
sigma_array = np.zeros(20)
error = np.zeros(20)
for k in range(20):
    sigma = 0.05*(k+1)
    sigma_array[k] = sigma
    delta_w = np.zeros(N)
    weights = np.random.normal(1, 1, N)
    hidden_out = np.zeros((n, N))
    for i in range(n):
        for j in range(N):
            hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
        train_result = np.dot(hidden_out[i], weights)
        train_error = y_train[i] - train_result
        delta_w = rate*train_error*hidden_out[i]
        weights = weights + delta_w
    hidden_out2 = np.zeros((len(x_test), N))
    results = np.zeros(len(x_test))
    for i in range(len(x_test)):
        for j in range(N):
            hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_test[i]-centers[j]))
        results[i] = np.dot(hidden_out2[i], weights)
    error[k] = np.mean(np.abs(y_test - results))
plt.plot(sigma_array, error, label='Number of nodes = 7')

step2 = 0.5
centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
sigma_array = np.zeros(20)
error = np.zeros(20)
for k in range(20):
    sigma = 0.05*(k+1)
    sigma_array[k] = sigma
    delta_w = np.zeros(N)
    weights = np.random.normal(1, 1, N)
    hidden_out = np.zeros((n, N))
    for i in range(n):
        for j in range(N):
            hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
        train_result = np.dot(hidden_out[i], weights)
        train_error = y_train[i] - train_result
        delta_w = rate*train_error*hidden_out[i]
        weights = weights + delta_w
    hidden_out2 = np.zeros((len(x_test), N))
    results = np.zeros(len(x_test))
    for i in range(len(x_test)):
        for j in range(N):
            hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_test[i]-centers[j]))
        results[i] = np.dot(hidden_out2[i], weights)
    error[k] = np.mean(np.abs(y_test - results))
plt.plot(sigma_array, error, label='Number of nodes = 13')

plt.xlabel('sigma')
plt.ylabel('Error on test set')
plt.title('The effect of the number of RBF nodes and the width of RBFs')
plt.legend()
plt.show()

# %% [markdown]
# In general, it can get better performance on test set if we set more RBF nodes. But number of RBF nodes should be more than the dimension of input space (in this case, the dimension of input space is 1) and less than the number of training examples.
# The width of RBFs can control the effect of each center on its neighbouring points. If sigma is small, the centers can affect the points in a bigger area. If sigma is large, the centers can affect the points just in a very small area. We should choose reasonable width of RBFs according to the number of RBF nodes, e.g.,when we have more nodes, we should decrease the width.

# %%
import math as math
import numpy as np

step = 0.1
x_train = np.arange(0, 2*math.pi, step)
np.random.shuffle(x_train)
x_test = np.arange(0.05, 2*math.pi, step)
y_train = np.zeros(len(x_train))
y_test = np.zeros(len(x_test))
n = len(x_train)
for i in range(n):
    y_train[i] = math.sin(2*x_train[i])
for i in range(len(x_test)):
    y_test[i] = math.sin(2*x_test[i])
# noise = np.random.normal(0, 0.1, len(y_train))
# y_train = y_train + noise
# y_test = y_test + noise

step2 = 0.5
rate = 0.05
centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
error = np.zeros(n)
sigma = 0.25
delta_w = np.zeros(N)
weights = np.random.normal(1, 1, N)
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
    train_result = np.dot(hidden_out[i], weights)
    error1 = y_train[i] - train_result
    delta_w = rate*error1*hidden_out[i]
    weights = weights + delta_w
    hidden_out2 = np.zeros((len(x_train), N))
    results = np.zeros(len(x_train))
    for k in range(len(x_train)):
        for m in range(N):
            hidden_out2[k][m] = math.exp(-0.5/sigma/sigma*np.square(x_train[k]-centers[m]))
        results[k] = np.dot(hidden_out2[k], weights)
    error[i] = np.mean(np.abs(y_train - results))
epoch = range(1, n+1)
error = np.abs(error)
plt.plot(epoch, error, color='red', label='eta=0.05')

step2 = 0.5
rate = 0.1
centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
error = np.zeros(n)
sigma = 0.25
delta_w = np.zeros(N)
weights = np.random.normal(1, 1, N)
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
    train_result = np.dot(hidden_out[i], weights)
    error1 = y_train[i] - train_result
    delta_w = rate*error1*hidden_out[i]
    weights = weights + delta_w
    hidden_out2 = np.zeros((len(x_train), N))
    results = np.zeros(len(x_train))
    for k in range(len(x_train)):
        for m in range(N):
            hidden_out2[k][m] = math.exp(-0.5/sigma/sigma*np.square(x_train[k]-centers[m]))
        results[k] = np.dot(hidden_out2[k], weights)
    error[i] = np.mean(np.abs(y_train - results))
epoch = range(1, n+1)
error = np.abs(error)
plt.plot(epoch, error, color='blue', label='eta=0.1')

step2 = 0.5
rate = 0.2
centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
error = np.zeros(n)
sigma = 0.25
delta_w = np.zeros(N)
weights = np.random.normal(1, 1, N)
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
    train_result = np.dot(hidden_out[i], weights)
    error1 = y_train[i] - train_result
    delta_w = rate*error1*hidden_out[i]
    weights = weights + delta_w
    hidden_out2 = np.zeros((len(x_train), N))
    results = np.zeros(len(x_train))
    for k in range(len(x_train)):
        for m in range(N):
            hidden_out2[k][m] = math.exp(-0.5/sigma/sigma*np.square(x_train[k]-centers[m]))
        results[k] = np.dot(hidden_out2[k], weights)
    error[i] = np.mean(np.abs(y_train - results))
epoch = range(1, n+1)
error = np.abs(error)
plt.plot(epoch, error, color='green', label='eta=0.2')

step2 = 0.5
rate = 0.3
centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
error = np.zeros(n)
sigma = 0.25
delta_w = np.zeros(N)
weights = np.random.normal(1, 1, N)
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
    train_result = np.dot(hidden_out[i], weights)
    error1 = y_train[i] - train_result
    delta_w = rate*error1*hidden_out[i]
    weights = weights + delta_w
    hidden_out2 = np.zeros((len(x_train), N))
    results = np.zeros(len(x_train))
    for k in range(len(x_train)):
        for m in range(N):
            hidden_out2[k][m] = math.exp(-0.5/sigma/sigma*np.square(x_train[k]-centers[m]))
        results[k] = np.dot(hidden_out2[k], weights)
    error[i] = np.mean(np.abs(y_train - results))
epoch = range(1, n+1)
error = np.abs(error)
plt.plot(epoch, error, color='black', label='eta=0.3')

plt.xlabel('Epoch')
plt.ylabel('Error on training set')
plt.title('The dependence of convergence rate on learning rate eta')
plt.legend()
plt.show()

# %% [markdown]
# In this case, the rate of convergence depends much on the learning rate, eta. As we can see in the figure above, it converges more quickly as eta gets larger. But a too large eta could cause us to miss the optimum.

# %%
import math as math
import numpy as np
import random

step = 0.1
x_train = np.arange(0, 2*math.pi, step)
np.random.shuffle(x_train)
x_test = np.arange(0.05, 2*math.pi, step)
y_train = np.zeros(len(x_train))
y_test = np.zeros(len(x_test))
n = len(x_train)
for i in range(n):
    y_train[i] = math.sin(2*x_train[i])
for i in range(len(x_test)):
    y_test[i] = math.sin(2*x_test[i])
noise = np.random.normal(0, 0.1, len(y_train))
y_train = y_train + noise
y_test = y_test + noise

sigma = 0.25

rate = 0.3
N = 13
centers = np.zeros(N)
for i in range(N):
    centers[i] = random.uniform(0, 2*math.pi)
delta_w = np.zeros(N)

hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
    train_result = np.dot(hidden_out[i], weights)
    train_error = y_train[i] - train_result
    delta_w = rate*train_error*hidden_out[i]
    weights = weights + delta_w

hidden_out2 = np.zeros((len(x_test), N))
results = np.zeros(len(x_test))
for i in range(len(x_test)):
    for j in range(N):
        hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_test[i]-centers[j]))
    results[i] = np.dot(hidden_out2[i], weights)

error = np.mean(np.abs(y_test - results))
print('Error of random intialization:', error)
# Out:
# Error of random intialization: 0.32184128619526603

# %% [markdown]
# The positioning of the RBF nodes is very important. The closer a point is to a center, the more it will be affected by the center. Random positioning is not a good strategy because all centers have the same width and if we randomly intialize the centers, we may just give "importance" to some points instead of all the points. A better strategy, which we use, is symmetric and uniform distribution over the range [0,2*pi]
# As we can see from the result above, if we randomly initialize the centers, the error on the test dataset is much larger.

# %%
import math as math
import numpy as np

step = 0.1
x_train = np.arange(0, 2*math.pi, step)
np.random.shuffle(x_train)
x_test = np.arange(0.05, 2*math.pi, step)
y_train = np.zeros(len(x_train))
y_test = np.zeros(len(x_test))
n = len(x_train)
for i in range(n):
    y_train[i] = math.sin(2*x_train[i])
for i in range(len(x_test)):
    y_test[i] = math.sin(2*x_test[i])
noise = np.random.normal(0, 0.1, len(y_train))
y_train = y_train + noise
# y_test = y_test + noise

step2 = 0.5
sigma = 0.3

rate = 0.3
centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
delta_w = np.zeros(N)

hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
    train_result = np.dot(hidden_out[i], weights)
    train_error = y_train[i] - train_result
    delta_w = rate*train_error*hidden_out[i]
    weights = weights + delta_w

print(weights)
hidden_out2 = np.zeros((len(x_test), N))
results = np.zeros(len(x_test))
for i in range(len(x_test)):
    for j in range(N):
        hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_test[i]-centers[j]))
    results[i] = np.dot(hidden_out2[i], weights)

error = np.mean(np.abs(y_test - results))
print('Error:', error)
plt.plot(x_test, results, color='red',label='Predicted data')
plt.plot(x_test, y_test, color='blue', label='Test data')
plt.legend()
plt.title('Performance on test set')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# [ 0.29934823  0.36634984  0.83323226  0.08534299 -0.69673735 -0.6871708
#  -0.24830145  0.46809658  0.87847732  0.23550344 -0.40685243 -0.78816708
#  -0.37878078]
# Error: 0.05774521130367101

# %% [markdown]
# The test performance on the original clean data is better than that on noisy data comparing to section 3.1.

# %%
import math as math
import numpy as np
import random
import matplotlib.pyplot as plt

step = 0.1
x_train = np.arange(0, 2*math.pi, step)
# np.random.shuffle(x_train)
x_test = np.arange(0.05, 2*math.pi, step)
y_train = np.zeros(len(x_train))
y_test = np.zeros(len(x_test))
n = len(x_train)
for i in range(n): y_train[i] = math.sin(2*x_train[i])
for i in range(len(x_test)): y_test[i] = math.sin(2*x_test[i])
# noise = np.random.normal(0, 0.1, len(y_train))
# y_train = y_train + noise
# y_test = y_test + noise

N = 13
centers = np.random.normal(3, 1, N)
temp = np.zeros(N)
sigma = 0.25
rate1 = 0.2
epoch = 5000
for i in range(epoch):
    x = random.choice(x_train)
    a = float('inf')
    for j in range(N):
        temp[j] = (x - centers[j])*(x - centers[j])
        if temp[j] < a:
            index = j
            a = temp[j]
    centers[index] += rate1*(x - centers[index])

plt.scatter(centers, np.zeros(N), color='red', label='centers')
plt.title('Result of position of nodes using CL approach')
plt.xlabel('x')
plt.legend()
plt.show()

weights = np.random.rand(N)
delta_w = np.zeros(N)
rate = 0.3
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
    train_result = np.dot(hidden_out[i], weights)
    train_error = y_train[i] - train_result
    delta_w = rate*train_error*hidden_out[i]
    weights = weights + delta_w

# print(weights)
hidden_out2 = np.zeros((len(x_test), N))
results = np.zeros(len(x_test))
for i in range(len(x_test)):
    for j in range(N):
        hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_test[i]-centers[j]))
    results[i] = np.dot(hidden_out2[i], weights)

error = np.mean(np.abs(y_test - results))
print('Error: ',error)
plt.plot(x_test, results, color='red', label='Predicted data')
plt.plot(x_test, y_test, color='blue', label='Test data')
plt.legend()
plt.title('Result of competitive learning on test set')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# Error:  0.235629114149335

# %% [markdown]
# CL, noise-free.
# The cluster centers found by competitive is very close to uniform distribution. The performance of CL is not good as that of manually positioning.

# %%
import math as math
import numpy as np
import random
import matplotlib.pyplot as plt

step = 0.1
x_train = np.arange(0, 2*math.pi, step)
# np.random.shuffle(x_train)
x_test = np.arange(0.05, 2*math.pi, step)
y_train = np.zeros(len(x_train))
y_test = np.zeros(len(x_test))
n = len(x_train)
for i in range(n): y_train[i] = math.sin(2*x_train[i])
for i in range(len(x_test)): y_test[i] = math.sin(2*x_test[i])
noise = np.random.normal(0, 0.1, len(y_train))
y_train = y_train + noise
y_test = y_test + noise

N = 13
centers = np.random.normal(3, 1, N)
temp = np.zeros(N)
sigma = 0.25
rate1 = 0.2
epoch = 5000
for i in range(epoch):
    x = random.choice(x_train)
    a = float('inf')
    for j in range(N):
        temp[j] = (x - centers[j])*(x - centers[j])
        if temp[j] < a:
            index = j
            a = temp[j]
    centers[index] += rate1*(x - centers[index])

print(centers)

weights = np.random.rand(N)
delta_w = np.zeros(N)
rate = 0.3
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
    train_result = np.dot(hidden_out[i], weights)
    train_error = y_train[i] - train_result
    delta_w = rate*train_error*hidden_out[i]
    weights = weights + delta_w

# print(weights)
hidden_out2 = np.zeros((len(x_test), N))
results = np.zeros(len(x_test))
for i in range(len(x_test)):
    for j in range(N):
        hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_test[i]-centers[j]))
    results[i] = np.dot(hidden_out2[i], weights)

error = np.mean(np.abs(y_test - results))
print(error)
plt.plot(x_test, results, color='red', label='Predicted data')
plt.plot(x_test, y_test, color='blue', label='Test data')
plt.legend()
plt.title('Result of competitive learning on test set')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# [3.33401953 3.79897091 4.85389307 0.29196592 5.27493866 2.88587775
#  1.85415466 2.34093053 0.91069423 6.07936047 1.46048317 4.25380475
#  5.63275692]
# 0.25908924933334615

# %% [markdown]
# CL, noisy.

# %%
import math as math
import numpy as np

step = 0.1
x_train = np.arange(0, 2*math.pi, step)
np.random.shuffle(x_train)
x_test = np.arange(0.05, 2*math.pi, step)
y_train = np.zeros(len(x_train))
y_test = np.zeros(len(x_test))
n = len(x_train)
for i in range(n):
    y_train[i] = math.sin(2*x_train[i])
for i in range(len(x_test)):
    y_test[i] = math.sin(2*x_test[i])
# noise = np.random.normal(0, 0.1, len(y_train))
# y_train = y_train + noise
# y_test = y_test + noise

step2 = 0.5
rate = 0.3
centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
error = np.zeros(n)
sigma = 0.25
delta_w = np.zeros(N)
weights = np.random.normal(1, 1, N)
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
    train_result = np.dot(hidden_out[i], weights)
    error1 = y_train[i] - train_result
    delta_w = rate*error1*hidden_out[i]
    weights = weights + delta_w
    hidden_out2 = np.zeros((len(x_train), N))
    results = np.zeros(len(x_train))
    for k in range(len(x_train)):
        for m in range(N):
            hidden_out2[k][m] = math.exp(-0.5/sigma/sigma*np.square(x_train[k]-centers[m]))
        results[k] = np.dot(hidden_out2[k], weights)
    error[i] = np.mean(np.abs(y_train - results))
epoch = range(1, n+1)
error = np.abs(error)
plt.plot(epoch, error, color='red', label='Manually position and noise-free')

N = 13
centers = np.random.normal(3, 1, N)
temp = np.zeros(N)
sigma = 0.25
rate1 = 0.2
epoch = 5000
for i in range(epoch):
    x = random.choice(x_train)
    a = float('inf')
    for j in range(N):
        temp[j] = (x - centers[j])*(x - centers[j])
        if temp[j] < a:
            index = j
            a = temp[j]
    centers[index] += rate1*(x - centers[index])
rate = 0.3
error = np.zeros(n)
sigma = 0.25
delta_w = np.zeros(N)
weights = np.random.normal(1, 1, N)
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
    train_result = np.dot(hidden_out[i], weights)
    error1 = y_train[i] - train_result
    delta_w = rate*error1*hidden_out[i]
    weights = weights + delta_w
    hidden_out2 = np.zeros((len(x_train), N))
    results = np.zeros(len(x_train))
    for k in range(len(x_train)):
        for m in range(N):
            hidden_out2[k][m] = math.exp(-0.5/sigma/sigma*np.square(x_train[k]-centers[m]))
        results[k] = np.dot(hidden_out2[k], weights)
    error[i] = np.mean(np.abs(y_train - results))
epoch = range(1, n+1)
error = np.abs(error)
plt.plot(epoch, error, color='blue', label='CL and noise-free')

noise = np.random.normal(0, 0.1, len(y_train))
y_train = y_train + noise
y_test = y_test + noise

step2 = 0.5
rate = 0.3
centers = np.arange(0, 2*math.pi, step2)
N = len(centers)
error = np.zeros(n)
sigma = 0.25
delta_w = np.zeros(N)
weights = np.random.normal(1, 1, N)
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
    train_result = np.dot(hidden_out[i], weights)
    error1 = y_train[i] - train_result
    delta_w = rate*error1*hidden_out[i]
    weights = weights + delta_w
    hidden_out2 = np.zeros((len(x_train), N))
    results = np.zeros(len(x_train))
    for k in range(len(x_train)):
        for m in range(N):
            hidden_out2[k][m] = math.exp(-0.5/sigma/sigma*np.square(x_train[k]-centers[m]))
        results[k] = np.dot(hidden_out2[k], weights)
    error[i] = np.mean(np.abs(y_train - results))
epoch = range(1, n+1)
error = np.abs(error)
plt.plot(epoch, error, color='green', label='Manually position and with noise')

N = 13
centers = np.random.normal(3, 1, N)
temp = np.zeros(N)
sigma = 0.25
rate1 = 0.2
epoch = 5000
for i in range(epoch):
    x = random.choice(x_train)
    a = float('inf')
    for j in range(N):
        temp[j] = (x - centers[j])*(x - centers[j])
        if temp[j] < a:
            index = j
            a = temp[j]
    centers[index] += rate1*(x - centers[index])
rate = 0.3
error = np.zeros(n)
sigma = 0.25
delta_w = np.zeros(N)
weights = np.random.normal(1, 1, N)
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*np.square(x_train[i]-centers[j]))
    train_result = np.dot(hidden_out[i], weights)
    error1 = y_train[i] - train_result
    delta_w = rate*error1*hidden_out[i]
    weights = weights + delta_w
    hidden_out2 = np.zeros((len(x_train), N))
    results = np.zeros(len(x_train))
    for k in range(len(x_train)):
        for m in range(N):
            hidden_out2[k][m] = math.exp(-0.5/sigma/sigma*np.square(x_train[k]-centers[m]))
        results[k] = np.dot(hidden_out2[k], weights)
    error[i] = np.mean(np.abs(y_train - results))
epoch = range(1, n+1)
error = np.abs(error)
plt.plot(epoch, error, color='black', label='CL and with noise')

plt.xlabel('Epoch')
plt.ylabel('Error on training set')
plt.title('Learning curve')
plt.legend()
plt.show()

# %% [markdown]
# To avoid dead units, we intialize cluster centers with input data samples. For example, if we just randomly intialize cluster centers and if some of these intialized centers are out of input space, then they will be dead units.

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math

train_set = np.loadtxt('./data_lab2/ballist.dat')
test_set = np.loadtxt('./data_lab2/balltest.dat')

x_train = train_set[:, 0:2]
y_train = train_set[:, 2:4]
x_test = test_set[:, 0:2]
y_test = test_set[:, 2:4]

N = 7
centers = np.zeros((N, 2))
centers[:, 0] = np.random.rand(N)
centers[:, 1] = np.random.rand(N)
temp = np.zeros(N)
sigma = 0.25
rate1 = 0.2
epoch = 5000
for i in range(epoch):
    x = random.choice(x_train)
    a = float('inf')
    for j in range(N):
        temp[j] = (x[0] - centers[j][0])*(x[0] - centers[j][0]) + (x[1] - centers[j][1])*(x[1] - centers[j][1])
        if temp[j] < a:
            index = j
            a = temp[j]
    centers[index] += rate1*(x - centers[index])

plt.scatter(centers[:, 0], centers[:, 1])
plt.title('Position of cluster centers using CL approach (7 units)')
plt.xlabel('angle')
plt.ylabel('velocity')
plt.show()

n = len(x_train)
weights = np.zeros((N, 2))
weights[:, 0] = np.random.rand(N)
weights[:, 1] = np.random.rand(N)
delta_w = np.zeros((N, 2))
delta_w = np.zeros((N, 2))
rate = 0.3
hidden_out = np.zeros((n, N))
for i in range(n):
    for j in range(N):
        hidden_out[i][j] = math.exp(-0.5/sigma/sigma*(np.square(x_train[i][0] - centers[j][0]) + np.square(x_train[i][1] - centers[j][1])))
    train_result = np.dot(hidden_out[i], weights)
    train_error = y_train[i] - train_result
    delta_w[:, 0] = rate*train_error[0]*hidden_out[i]
    delta_w[:, 1] = rate * train_error[1] * hidden_out[i]
    weights = weights + delta_w

# print(weights)
hidden_out2 = np.zeros((len(x_test), N))
results = np.zeros((len(x_test), 2))
for i in range(len(x_test)):
    for j in range(N):
        hidden_out2[i][j] = math.exp(-0.5/sigma/sigma*(np.square(x_test[i][0] - centers[j][0]) + np.square(x_test[i][1] - centers[j][1])))
    results[i] = np.dot(hidden_out2[i], weights)

error_dis = np.mean(np.abs(y_test[:, 0] - results[:, 0]))
error_hei = np.mean(np.abs(y_test[:, 1] - results[:, 1]))
print('Error of distance on test set: ', error_dis)
print('Error of height on test set: ', error_hei)
# plt.scatter(results[:, 0], color='red')
# plt.scatter(y_test[:, 0], color='blue')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-30-a15978e67c9b> in <module>
#       4 import math
#       5
# ----> 6 train_set = np.loadtxt('D:\\学习资料\\KTH\\ANN\\Lab\\Lab2\\ballist.dat')
#       7 test_set = np.loadtxt('D:\\学习资料\\KTH\\ANN\\Lab\\Lab2\\balltest.dat')
#       8
#
# ~/anaconda3/envs/ml/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     966             fname = os_fspath(fname)
#     967         if _is_string_like(fname):
# --> 968             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     969             fencoding = getattr(fh, 'encoding', 'latin1')
#     970             fh = iter(fh)
#
# ~/anaconda3/envs/ml/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# ~/anaconda3/envs/ml/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: D:\学习资料\KTH\ANN\Lab\Lab2\ballist.dat not found.
