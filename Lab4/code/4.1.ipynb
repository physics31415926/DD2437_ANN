# %%
from util import *
from rbm import RestrictedBoltzmannMachine 
from dbn import DeepBeliefNet
import matplotlib.pyplot as plt

image_size = [28,28]
train_imgs,train_lbls,test_imgs,test_lbls = read_mnist(dim=image_size, n_train=60000, n_test=10000)
''' restricted boltzmann machine '''

print ("\nStarting a Restricted Boltzmann Machine..")
Num_hidden_nodes = [200+100*i for i in range(4)]
mse=[]
for i in Num_hidden_nodes:
    rbm = RestrictedBoltzmannMachine(ndim_visible=image_size[0]*image_size[1],
                                        ndim_hidden=i,
                                        is_bottom=True,
                                        image_size=image_size,
                                        is_top=False,
                                        n_labels=10,
                                        batch_size=20,

    )
    mse.append(rbm.cd1(visible_trainset=train_imgs, n_iterations=20))
# Out:
# Starting a Restricted Boltzmann Machine..
# learning CD1
# iteration=      0 recon_loss=47.6334
# iteration=      1 recon_loss=45.5546
# iteration=      2 recon_loss=44.7176
# iteration=      3 recon_loss=44.0580
# iteration=      4 recon_loss=43.6427
# iteration=      5 recon_loss=43.4443
# iteration=      6 recon_loss=43.1680
# iteration=      7 recon_loss=42.0339
# iteration=      8 recon_loss=43.0385
# iteration=      9 recon_loss=43.0951
# iteration=     10 recon_loss=42.7347
# iteration=     11 recon_loss=42.5098
# iteration=     12 recon_loss=42.5833
# iteration=     13 recon_loss=42.5018
# iteration=     14 recon_loss=42.4906
# iteration=     15 recon_loss=42.1510
# iteration=     16 recon_loss=42.4061
# iteration=     17 recon_loss=41.9547
# iteration=     18 recon_loss=42.1751
# iteration=     19 recon_loss=41.7213
# learning CD1
# iteration=      0 recon_loss=46.7781
# iteration=      1 recon_loss=44.9920
# iteration=      2 recon_loss=43.9241
# iteration=      3 recon_loss=43.5909
# iteration=      4 recon_loss=43.2590
# iteration=      5 recon_loss=42.9193
# iteration=      6 recon_loss=42.4797
# iteration=      7 recon_loss=42.0306
# iteration=      8 recon_loss=42.0160
# iteration=      9 recon_loss=41.5971
# iteration=     10 recon_loss=41.8119
# iteration=     11 recon_loss=41.8191
# iteration=     12 recon_loss=41.6396
# iteration=     13 recon_loss=41.6670
# iteration=     14 recon_loss=41.5681
# iteration=     15 recon_loss=41.8059
# iteration=     16 recon_loss=41.1911
# iteration=     17 recon_loss=41.3661
# iteration=     18 recon_loss=40.9173
# iteration=     19 recon_loss=41.1343
# learning CD1
# iteration=      0 recon_loss=46.0865
# iteration=      1 recon_loss=44.2016
# iteration=      2 recon_loss=42.9038
# iteration=      3 recon_loss=43.0028
# iteration=      4 recon_loss=41.9964
# iteration=      5 recon_loss=42.7041
# iteration=      6 recon_loss=41.8540
# iteration=      7 recon_loss=41.0958
# iteration=      8 recon_loss=41.4902
# iteration=      9 recon_loss=40.8335
# iteration=     10 recon_loss=40.7566
# iteration=     11 recon_loss=40.5063
# iteration=     12 recon_loss=40.4870
# iteration=     13 recon_loss=40.5198
# iteration=     14 recon_loss=40.2302
# iteration=     15 recon_loss=40.3302
# iteration=     16 recon_loss=39.8743
# iteration=     17 recon_loss=39.6639
# iteration=     18 recon_loss=40.1326
# iteration=     19 recon_loss=40.1801
# learning CD1
# iteration=      0 recon_loss=45.5942
# iteration=      1 recon_loss=44.3772
# iteration=      2 recon_loss=43.8671
# iteration=      3 recon_loss=42.8924
# iteration=      4 recon_loss=43.0263
# iteration=      5 recon_loss=42.8658
# iteration=      6 recon_loss=42.4593
# iteration=      7 recon_loss=41.6740
# iteration=      8 recon_loss=41.8513
# iteration=      9 recon_loss=41.7366
# iteration=     10 recon_loss=41.0695
# iteration=     11 recon_loss=40.8031
# iteration=     12 recon_loss=41.2233
# iteration=     13 recon_loss=40.8748
# iteration=     14 recon_loss=40.6253
# iteration=     15 recon_loss=40.7508
# iteration=     16 recon_loss=40.4637
# iteration=     17 recon_loss=40.2794
# iteration=     18 recon_loss=40.4550
# iteration=     19 recon_loss=40.5437

# %%
for idx,i in enumerate(Num_hidden_nodes):
    plt.plot(mse[idx],label="%d hidden nodes"%i)
plt.title("mse over iterations with different hidden nodes")
plt.ylabel("MSE")
plt.xlabel("Epoch")
plt.legend()
plt.show()
